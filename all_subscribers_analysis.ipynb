# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np

# mpl.rcParams.update(mpl.rcParamsDefault)

# makes plots visible in pycharm
plt.style.use({'figure.facecolor':'white'})

PATH = 'Customer_report_1-13.csv'
PATH2 = 'all_customers_shopify_1-13.csv'
custRecharge = pd.read_csv(PATH, delimiter=',')
custShopify = pd.read_csv(PATH2, delimiter=',')

# %%
custRecharge.head()
# Out:
#    customer recharge id  ... First Charge Processed At
# 0              56865929  ...       2021-01-12 18:47:34
# 1              56860712  ...       2021-01-12 17:01:47
# 2              56854593  ...       2021-01-12 15:15:33
# 3              56824124  ...       2021-01-12 02:56:54
# 4              56821078  ...       2021-01-12 00:36:04
#
# [5 rows x 28 columns]

# %%
custRecharge.head(30)
# Out:
#     customer recharge id  ... First Charge Processed At
# 0               56865929  ...       2021-01-12 18:47:34
# 1               56860712  ...       2021-01-12 17:01:47
# 2               56854593  ...       2021-01-12 15:15:33
# 3               56824124  ...       2021-01-12 02:56:54
# 4               56821078  ...       2021-01-12 00:36:04
# 5               56811944  ...       2021-01-11 21:04:46
# 6               56810230  ...       2021-01-11 20:29:33
# 7               56809908  ...       2021-01-11 20:23:22
# 8               56794053  ...       2021-01-11 15:16:41
# 9               56777497  ...       2021-01-11 10:30:06
# 10              56768259  ...                       NaN
# 11              56768051  ...                       NaN
# 12              56746297  ...       2021-01-10 18:53:48
# 13              56745899  ...       2021-01-10 18:46:01
# 14              56743214  ...       2021-01-10 17:55:48
# 15              56728047  ...       2021-01-10 14:19:27
# 16              56726636  ...       2021-01-10 13:55:13
# 17              56719973  ...       2021-01-10 12:06:44
# 18              56698818  ...       2021-01-10 00:39:11
# 19              56696250  ...       2021-01-09 23:23:43
# 20              56692298  ...       2021-01-09 21:49:20
# 21              56684094  ...       2021-01-09 19:02:10
# 22              56672194  ...       2021-01-09 15:31:55
# 23              56654975  ...       2021-01-09 10:36:48
# 24              56651624  ...       2021-01-09 09:31:15
# 25              56637722  ...       2021-01-08 23:51:05
# 26              56635026  ...       2021-01-08 22:39:41
# 27              56625337  ...       2021-01-08 19:02:00
# 28              56625144  ...       2021-01-08 18:58:16
# 29              56623609  ...       2021-01-08 18:25:12
#
# [30 rows x 28 columns]

# %%
custRecharge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7083 entries, 0 to 7082
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   customer recharge id             7083 non-null   int64
#  1   customer first name              7079 non-null   object
#  2   customer last name               7083 non-null   object
#  3   customer email                   7083 non-null   object
#  4   created at                       7083 non-null   object
#  5   status                           7083 non-null   object
#  6   shipping address 1               7083 non-null   object
#  7   shipping address 2               1742 non-null   object
#  8   shipping city                    7083 non-null   object
#  9   shipping postal code             7042 non-null   object
#  10  shipping province                5930 non-null   object
#  11  shipping country                 7083 non-null   object
#  12  shipping_phone                   7046 non-null   object
#  13  portal_url                       7083 non-null   object
#  14  billing address 1                7079 non-null   object
#  15  billing address 2                1696 non-null   object
#  16  billing city                     7079 non-null   object
#  17  billing postal code              7035 non-null   object
#  18  billing province                 5930 non-null   object
#  19  billing country                  7082 non-null   object
#  20  Shopify customer id              7083 non-null   int64
#  21  Past Orders Count                7083 non-null   int64
#  22  Has Valid Payment Method         7083 non-null   bool
#  23  Reason Payment Method Not Valid  594 non-null    object
#  24  Has Card Error In Dunning        7083 non-null   bool
#  25  Number Active Subscriptions      7083 non-null   int64
#  26  Number Subscriptions             7083 non-null   int64
#  27  First Charge Processed At        7077 non-null   object
# dtypes: bool(2), int64(5), object(21)
# memory usage: 1.4+ MB

# %%
custShopify.head()
# Out:
#   First Name Last Name                     Email  ... Tags Note Tax Exempt
# 0      Micah  Jumaquio      micahjumaq@gmail.com  ...  NaN  NaN         no
# 1      Alain      Tran       sillywiener@aol.com  ...  NaN  NaN         no
# 2     Nickie   Venegas    dhv2350@email.vccs.edu  ...  NaN  NaN         no
# 3   Victoria    Morris   tori-morris@hotmail.com  ...  NaN  NaN         no
# 4   Manjusha    Punugu  manjushapunugu@gmail.com  ...  NaN  NaN         no
#
# [5 rows x 19 columns]

# %%
custShopify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52406 entries, 0 to 52405
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         43983 non-null  object
#  1   Last Name          43722 non-null  object
#  2   Email              52230 non-null  object
#  3   Company            319 non-null    object
#  4   Address1           20401 non-null  object
#  5   Address2           4802 non-null   object
#  6   City               20410 non-null  object
#  7   Province           17085 non-null  object
#  8   Province Code      17067 non-null  object
#  9   Country            20421 non-null  object
#  10  Country Code       20421 non-null  object
#  11  Zip                20248 non-null  object
#  12  Phone              20343 non-null  object
#  13  Accepts Marketing  52406 non-null  object
#  14  Total Spent        52406 non-null  float64
#  15  Total Orders       52406 non-null  int64
#  16  Tags               18745 non-null  object
#  17  Note               63 non-null     object
#  18  Tax Exempt         52406 non-null  object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 7.6+ MB

# %%
custRecharge['status'] = custRecharge['status'].str.lower()

# %%
custRecharge['status'].value_counts()
# Out:
# inactive                         3418
# active                           3075
# inactive, max retries reached     567
# active, has order error            17
# inactive, expired                   6
# Name: status, dtype: int64

# %%
custRecharge['Number Subscriptions'].value_counts()
# Out:
# 1     6296
# 2      637
# 3      121
# 4       17
# 5        7
# 6        3
# 7        1
# 10       1
# Name: Number Subscriptions, dtype: int64

# %%
custRecharge.rename(columns={'customer email' : 'Email'}, inplace=True)

# %%
mergedDf = custRecharge.merge(custShopify, how='inner', on='Email')
mergedDf.to_csv("MergedDf.csv")

# %%
mergedDf.head(30)
# Out:
#     customer recharge id customer first name  ... Note Tax Exempt
# 0               56865929              Sarahi  ...  NaN         no
# 1               56860712               Grace  ...  NaN         no
# 2               56854593           Marymegan  ...  NaN         no
# 3               56824124                 Kia  ...  NaN         no
# 4               56821078                Sara  ...  NaN         no
# 5               56811944              Lauren  ...  NaN         no
# 6               56810230             Chinika  ...  NaN         no
# 7               56809908              Ginger  ...  NaN         no
# 8               56768259           Alexandra  ...  NaN         no
# 9               56768051            Claretny  ...  NaN         no
# 10              56746297                Mary  ...  NaN         no
# 11              56745899               Jenna  ...  NaN         no
# 12              56743214                Koda  ...  NaN         no
# 13              56728047              Deonna  ...  NaN         no
# 14              56726636              Deonna  ...  NaN         no
# 15              56719973             Jessica  ...  NaN         no
# 16              56698818               Elwin  ...  NaN         no
# 17              56696250              Alivia  ...  NaN         no
# 18              56692298                Zoey  ...  NaN         no
# 19              56684094               Susan  ...  NaN         no
# 20              56672194              Olivia  ...  NaN         no
# 21              56654975               linda  ...  NaN         no
# 22              56651624               Carly  ...  NaN         no
# 23              56637722              Catlyn  ...  NaN         no
# 24              56635026              Hannah  ...  NaN         no
# 25              56625144           Christina  ...  NaN         no
# 26              56623609               Susan  ...  NaN         no
# 27              56622020               Sarah  ...  NaN         no
# 28              56607872             Jasmine  ...  NaN         no
# 29              56562229               Katie  ...  NaN         no
#
# [30 rows x 46 columns]

# %%
mergedDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6967 entries, 0 to 6966
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   customer recharge id             6967 non-null   int64
#  1   customer first name              6963 non-null   object
#  2   customer last name               6967 non-null   object
#  3   Email                            6967 non-null   object
#  4   created at                       6967 non-null   object
#  5   status                           6967 non-null   object
#  6   shipping address 1               6967 non-null   object
#  7   shipping address 2               1710 non-null   object
#  8   shipping city                    6967 non-null   object
#  9   shipping postal code             6926 non-null   object
#  10  shipping province                5827 non-null   object
#  11  shipping country                 6967 non-null   object
#  12  shipping_phone                   6931 non-null   object
#  13  portal_url                       6967 non-null   object
#  14  billing address 1                6963 non-null   object
#  15  billing address 2                1663 non-null   object
#  16  billing city                     6963 non-null   object
#  17  billing postal code              6919 non-null   object
#  18  billing province                 5827 non-null   object
#  19  billing country                  6966 non-null   object
#  20  Shopify customer id              6967 non-null   int64
#  21  Past Orders Count                6967 non-null   int64
#  22  Has Valid Payment Method         6967 non-null   bool
#  23  Reason Payment Method Not Valid  581 non-null    object
#  24  Has Card Error In Dunning        6967 non-null   bool
#  25  Number Active Subscriptions      6967 non-null   int64
#  26  Number Subscriptions             6967 non-null   int64
#  27  First Charge Processed At        6961 non-null   object
#  28  First Name                       6963 non-null   object
#  29  Last Name                        6966 non-null   object
#  30  Company                          231 non-null    object
#  31  Address1                         6930 non-null   object
#  32  Address2                         1693 non-null   object
#  33  City                             6932 non-null   object
#  34  Province                         5804 non-null   object
#  35  Province Code                    5792 non-null   object
#  36  Country                          6932 non-null   object
#  37  Country Code                     6932 non-null   object
#  38  Zip                              6889 non-null   object
#  39  Phone                            6913 non-null   object
#  40  Accepts Marketing                6967 non-null   object
#  41  Total Spent                      6967 non-null   float64
#  42  Total Orders                     6967 non-null   int64
#  43  Tags                             6958 non-null   object
#  44  Note                             58 non-null     object
#  45  Tax Exempt                       6967 non-null   object
# dtypes: bool(2), float64(1), int64(6), object(37)
# memory usage: 2.4+ MB

# %% [markdown]
# ## 1. Customer engagement (active vs inactive)

# %%
mergedDf['Accepts Marketing']
# Out:
# 0       yes
# 1       yes
# 2        no
# 3        no
# 4       yes
#        ...
# 6962    yes
# 6963    yes
# 6964    yes
# 6965    yes
# 6966    yes
# Name: Accepts Marketing, Length: 6967, dtype: object

# %%
mergedDf['Accepts Marketing'] = mergedDf['Accepts Marketing'].apply(lambda x: 0 if x=='no' else 1)

# %%
mergedDf['engaged'] = mergedDf['status'].apply(lambda x: 0 if x=='inactive' else 1)

# %%
marketing_by_status_df = pd.DataFrame(mergedDf.groupby('engaged').count()['status'] / mergedDf.shape[0] * 100)

# %%
marketing_by_status_df
# Out:
#             status
# engaged
# 0        48.342185
# 1        51.657815

# %%
marketing_by_status_df.T
# Out:
# engaged          0          1
# status   48.342185  51.657815

# %% [markdown]
# #### a. engagement by number of subscriptions

# %%
mergedDf['Number Subscriptions'].value_counts()
# Out:
# 1     6192
# 2      628
# 3      119
# 4       16
# 5        7
# 6        3
# 7        1
# 10       1
# Name: Number Subscriptions, dtype: int64

# %%
engagement_by_sub_type_df = pd.pivot_table(
    mergedDf,
    values='status',
    index='Number Subscriptions',
    columns='engaged',
    aggfunc=len
).fillna(0.0)

engagement_by_sub_type_df.columns = ['Not Engaged', 'Engaged']

# %%
engagement_by_sub_type_df
# Out:
#                       Not Engaged  Engaged
# Number Subscriptions
# 1                          3155.0   3037.0
# 2                           191.0    437.0
# 3                            19.0    100.0
# 4                             1.0     15.0
# 5                             1.0      6.0
# 6                             0.0      3.0
# 7                             0.0      1.0
# 10                            1.0      0.0

# %% [markdown]
# #### b. engagement by country

# %%
mergedDf['Country'].value_counts()
# Out:
# United States     4966
# Canada             302
# United Kingdom     260
# Germany            246
# Australia          181
#                   ...
# Belarus              1
# Estonia              1
# Sri Lanka            1
# Martinique           1
# Jersey               1
# Name: Country, Length: 65, dtype: int64

# %% [markdown]
# #### showing engagement by countries in numbers

# %%
engagement_by_country_df = pd.pivot_table(
    mergedDf,
    values='status',
    index='Country',
    columns='engaged',
    aggfunc=len
).fillna(0.0)

pd.set_option("display.max_rows", None, "display.max_columns", None, 'display.max_colwidth', None)


engagement_by_country_df.columns = ['Not Engaged', 'Engaged']
engagement_by_country_df.sort_values(ascending=False, by=['Not Engaged', 'Engaged']).rename_axis(None, axis=1).reset_index()
# Out:
#                  Country  Not Engaged  Engaged
# 0          United States       2156.0   2810.0
# 1                 Canada        159.0    143.0
# 2                Germany        149.0     97.0
# 3         United Kingdom        147.0    113.0
# 4              Australia         93.0     88.0
# 5                 France         92.0     54.0
# 6              Singapore         40.0     22.0
# 7                 Mexico         38.0     13.0
# 8                  Spain         32.0     17.0
# 9            Netherlands         32.0     10.0
# 10                 India         31.0      5.0
# 11               Denmark         28.0     14.0
# 12               Austria         27.0      2.0
# 13           Switzerland         22.0     25.0
# 14                 Italy         22.0      8.0
# 15           New Zealand         20.0     10.0
# 16               Belgium         19.0     12.0
# 17               Ireland         16.0      6.0
# 18                Norway         13.0     17.0
# 19                Sweden         13.0     10.0
# 20             Hong Kong         11.0      6.0
# 21                Poland         11.0      4.0
# 22           Philippines         10.0     21.0
# 23               Hungary         10.0      5.0
# 24        Czech Republic         10.0      3.0
# 25              Portugal         10.0      1.0
# 26          Saudi Arabia          9.0     10.0
# 27  United Arab Emirates          9.0      7.0
# 28              Thailand          9.0      3.0
# 29                Israel          8.0      4.0
# 30              Malaysia          7.0     10.0
# 31                 Qatar          7.0      6.0
# 32               Finland          7.0      2.0
# 33                  Peru          7.0      0.0
# 34                 Japan          6.0     15.0
# 35               Romania          6.0      2.0
# 36                 Chile          5.0      5.0
# 37              Slovakia          5.0      1.0
# 38               Croatia          5.0      0.0
# 39              Bulgaria          4.0      0.0
# 40             Lithuania          4.0      0.0
# 41            Luxembourg          4.0      0.0
# 42           South Korea          4.0      0.0
# 43              Colombia          3.0      0.0
# 44                Taiwan          2.0      2.0
# 45                Turkey          2.0      1.0
# 46                Brunei          2.0      0.0
# 47               Vietnam          2.0      0.0
# 48               Ecuador          1.0      1.0
# 49               Iceland          1.0      1.0
# 50               Belarus          1.0      0.0
# 51            Costa Rica          1.0      0.0
# 52                Cyprus          1.0      0.0
# 53    Dominican Republic          1.0      0.0
# 54                Greece          1.0      0.0
# 55                Latvia          1.0      0.0
# 56                 Malta          1.0      0.0
# 57         New Caledonia          1.0      0.0
# 58             Sri Lanka          1.0      0.0
# 59               Bahrain          0.0      2.0
# 60               Estonia          0.0      1.0
# 61              Guernsey          0.0      1.0
# 62                Jersey          0.0      1.0
# 63            Martinique          0.0      1.0
# 64  Moldova, Republic of          0.0      1.0

# %% [markdown]
# #### showing engagement by countries on percentage

# %%
func = lambda x: 100*x.count()/mergedDf.shape[0]

engagement_by_country_df = pd.pivot_table(
    mergedDf,
    values='status',
    index='Country',
    columns='engaged',
    aggfunc=func
).fillna(0.0)

# %%
engagement_by_country_df.columns = ['Not Engaged', 'Engaged']
engagement_by_country_df = engagement_by_country_df.sort_values(ascending=False, by=['Not Engaged', 'Engaged'])

# %%
countries_only = mergedDf['Country']
countries_count = countries_only.value_counts().rename_axis('Country').reset_index(name='Total')
countries_count
# Out:
#                  Country  Total
# 0          United States   4966
# 1                 Canada    302
# 2         United Kingdom    260
# 3                Germany    246
# 4              Australia    181
# 5                 France    146
# 6              Singapore     62
# 7                 Mexico     51
# 8                  Spain     49
# 9            Switzerland     47
# 10           Netherlands     42
# 11               Denmark     42
# 12                 India     36
# 13           Philippines     31
# 14               Belgium     31
# 15           New Zealand     30
# 16                Norway     30
# 17                 Italy     30
# 18               Austria     29
# 19                Sweden     23
# 20               Ireland     22
# 21                 Japan     21
# 22          Saudi Arabia     19
# 23              Malaysia     17
# 24             Hong Kong     17
# 25  United Arab Emirates     16
# 26                Poland     15
# 27               Hungary     15
# 28        Czech Republic     13
# 29                 Qatar     13
# 30              Thailand     12
# 31                Israel     12
# 32              Portugal     11
# 33                 Chile     10
# 34               Finland      9
# 35               Romania      8
# 36                  Peru      7
# 37              Slovakia      6
# 38               Croatia      5
# 39           South Korea      4
# 40                Taiwan      4
# 41             Lithuania      4
# 42            Luxembourg      4
# 43              Bulgaria      4
# 44                Turkey      3
# 45              Colombia      3
# 46               Iceland      2
# 47               Ecuador      2
# 48               Vietnam      2
# 49               Bahrain      2
# 50                Brunei      2
# 51  Moldova, Republic of      1
# 52                Latvia      1
# 53         New Caledonia      1
# 54              Guernsey      1
# 55            Costa Rica      1
# 56                Cyprus      1
# 57                 Malta      1
# 58                Greece      1
# 59    Dominican Republic      1
# 60               Belarus      1
# 61               Estonia      1
# 62             Sri Lanka      1
# 63            Martinique      1
# 64                Jersey      1

# %%
new = pd.merge(engagement_by_country_df, countries_count, on='Country', how='left')
new
# Out:
#                  Country  Not Engaged    Engaged  Total
# 0          United States    30.945888  40.332998   4966
# 1                 Canada     2.282187   2.052533    302
# 2                Germany     2.138654   1.392278    246
# 3         United Kingdom     2.109947   1.621932    260
# 4              Australia     1.334864   1.263097    181
# 5                 France     1.320511   0.775083    146
# 6              Singapore     0.574135   0.315774     62
# 7                 Mexico     0.545428   0.186594     51
# 8                  Spain     0.459308   0.244007     49
# 9            Netherlands     0.459308   0.143534     42
# 10                 India     0.444955   0.071767     36
# 11               Denmark     0.401895   0.200947     42
# 12               Austria     0.387541   0.028707     29
# 13           Switzerland     0.315774   0.358835     47
# 14                 Italy     0.315774   0.114827     30
# 15           New Zealand     0.287068   0.143534     30
# 16               Belgium     0.272714   0.172241     31
# 17               Ireland     0.229654   0.086120     22
# 18                Norway     0.186594   0.244007     30
# 19                Sweden     0.186594   0.143534     23
# 20             Hong Kong     0.157887   0.086120     17
# 21                Poland     0.157887   0.057414     15
# 22           Philippines     0.143534   0.301421     31
# 23               Hungary     0.143534   0.071767     15
# 24        Czech Republic     0.143534   0.043060     13
# 25              Portugal     0.143534   0.014353     11
# 26          Saudi Arabia     0.129180   0.143534     19
# 27  United Arab Emirates     0.129180   0.100474     16
# 28              Thailand     0.129180   0.043060     12
# 29                Israel     0.114827   0.057414     12
# 30              Malaysia     0.100474   0.143534     17
# 31                 Qatar     0.100474   0.086120     13
# 32               Finland     0.100474   0.028707      9
# 33                  Peru     0.100474   0.000000      7
# 34                 Japan     0.086120   0.215301     21
# 35               Romania     0.086120   0.028707      8
# 36                 Chile     0.071767   0.071767     10
# 37              Slovakia     0.071767   0.014353      6
# 38               Croatia     0.071767   0.000000      5
# 39              Bulgaria     0.057414   0.000000      4
# 40             Lithuania     0.057414   0.000000      4
# 41            Luxembourg     0.057414   0.000000      4
# 42           South Korea     0.057414   0.000000      4
# 43              Colombia     0.043060   0.000000      3
# 44                Taiwan     0.028707   0.028707      4
# 45                Turkey     0.028707   0.014353      3
# 46                Brunei     0.028707   0.000000      2
# 47               Vietnam     0.028707   0.000000      2
# 48               Ecuador     0.014353   0.014353      2
# 49               Iceland     0.014353   0.014353      2
# 50               Belarus     0.014353   0.000000      1
# 51            Costa Rica     0.014353   0.000000      1
# 52                Cyprus     0.014353   0.000000      1
# 53    Dominican Republic     0.014353   0.000000      1
# 54                Greece     0.014353   0.000000      1
# 55                Latvia     0.014353   0.000000      1
# 56                 Malta     0.014353   0.000000      1
# 57         New Caledonia     0.014353   0.000000      1
# 58             Sri Lanka     0.014353   0.000000      1
# 59               Bahrain     0.000000   0.028707      2
# 60               Estonia     0.000000   0.014353      1
# 61              Guernsey     0.000000   0.014353      1
# 62                Jersey     0.000000   0.014353      1
# 63            Martinique     0.000000   0.014353      1
# 64  Moldova, Republic of     0.000000   0.014353      1

# %% [markdown]
# #### c. engagement by  marketing acceptance

# %%
engagement_by_marketing = pd.pivot_table(
    mergedDf,
    values='status',
    index='Accepts Marketing',
    columns='engaged',
    aggfunc=len
).fillna(0.0)

engagement_by_marketing.columns = ['Not Engaged', 'Engaged']

# %% [markdown]
# ##### Accepts Marketing = Subscribed to newletter - 0 means no, 1 means yes

# %%
engagement_by_marketing
# Out:
#                    Not Engaged  Engaged
# Accepts Marketing
# 0                          778      624
# 1                         2590     2975

# %% [markdown]
# ## Correlation

# %% [markdown]
# #### Feature Engineering - subscription duration

# %%
pearsons = mergedDf.corr()

# %%
pearsons
# Out:
#                              customer recharge id  Shopify customer id  \
# customer recharge id                     1.000000             0.938432
# Shopify customer id                      0.938432             1.000000
# Past Orders Count                       -0.236989            -0.205634
# Has Valid Payment Method                 0.114949             0.104194
# Has Card Error In Dunning                0.022832             0.022161
# Number Active Subscriptions              0.218087             0.185981
# Number Subscriptions                    -0.047870            -0.056778
# Accepts Marketing                       -0.059528            -0.061208
# Total Spent                             -0.187595            -0.206376
# Total Orders                            -0.304058            -0.312978
# engaged                                  0.189643             0.161467
#
#                              Past Orders Count  Has Valid Payment Method  \
# customer recharge id                 -0.236989                  0.114949
# Shopify customer id                  -0.205634                  0.104194
# Past Orders Count                     1.000000                  0.100324
# Has Valid Payment Method              0.100324                  1.000000
# Has Card Error In Dunning            -0.008219                 -0.056022
# Number Active Subscriptions           0.365963                  0.208086
# Number Subscriptions                  0.399459                  0.033860
# Accepts Marketing                     0.091255                 -0.029094
# Total Spent                           0.361969                  0.115421
# Total Orders                          0.479849                  0.117753
# engaged                               0.250373                 -0.239751
#
#                              Has Card Error In Dunning  \
# customer recharge id                          0.022832
# Shopify customer id                           0.022161
# Past Orders Count                            -0.008219
# Has Valid Payment Method                     -0.056022
# Has Card Error In Dunning                     1.000000
# Number Active Subscriptions                   0.015032
# Number Subscriptions                         -0.005243
# Accepts Marketing                            -0.012628
# Total Spent                                  -0.003919
# Total Orders                                 -0.000140
# engaged                                      -0.017517
#
#                              Number Active Subscriptions  \
# customer recharge id                            0.218087
# Shopify customer id                             0.185981
# Past Orders Count                               0.365963
# Has Valid Payment Method                        0.208086
# Has Card Error In Dunning                       0.015032
# Number Active Subscriptions                     1.000000
# Number Subscriptions                            0.333154
# Accepts Marketing                               0.063499
# Total Spent                                     0.470833
# Total Orders                                    0.456126
# engaged                                         0.783912
#
#                              Number Subscriptions  Accepts Marketing  \
# customer recharge id                    -0.047870          -0.059528
# Shopify customer id                     -0.056778          -0.061208
# Past Orders Count                        0.399459           0.091255
# Has Valid Payment Method                 0.033860          -0.029094
# Has Card Error In Dunning               -0.005243          -0.012628
# Number Active Subscriptions              0.333154           0.063499
# Number Subscriptions                     1.000000           0.028267
# Accepts Marketing                        0.028267           1.000000
# Total Spent                              0.417654           0.130601
# Total Orders                             0.433615           0.145073
# engaged                                  0.143257           0.071815
#
#                              Total Spent  Total Orders   engaged
# customer recharge id           -0.187595     -0.304058  0.189643
# Shopify customer id            -0.206376     -0.312978  0.161467
# Past Orders Count               0.361969      0.479849  0.250373
# Has Valid Payment Method        0.115421      0.117753 -0.239751
# Has Card Error In Dunning      -0.003919     -0.000140 -0.017517
# Number Active Subscriptions     0.470833      0.456126  0.783912
# Number Subscriptions            0.417654      0.433615  0.143257
# Accepts Marketing               0.130601      0.145073  0.071815
# Total Spent                     1.000000      0.925667  0.347563
# Total Orders                    0.925667      1.000000  0.321785
# engaged                         0.347563      0.321785  1.000000

# %%
kendall = mergedDf.corr(method='kendall')

# %%
kendall
# Out:
#                              customer recharge id  Shopify customer id  \
# customer recharge id                     1.000000             0.951049
# Shopify customer id                      0.951049             1.000000
# Past Orders Count                       -0.161199            -0.156385
# Has Valid Payment Method                 0.081978             0.081925
# Has Card Error In Dunning                0.017310             0.017970
# Number Active Subscriptions              0.164077             0.156528
# Number Subscriptions                    -0.041853            -0.045960
# Accepts Marketing                       -0.039983            -0.047946
# Total Spent                             -0.134057            -0.138775
# Total Orders                            -0.265358            -0.266945
# engaged                                  0.129656             0.122946
#
#                              Past Orders Count  Has Valid Payment Method  \
# customer recharge id                 -0.161199                  0.081978
# Shopify customer id                  -0.156385                  0.081925
# Past Orders Count                     1.000000                  0.093625
# Has Valid Payment Method              0.093625                  1.000000
# Has Card Error In Dunning            -0.006971                 -0.056022
# Number Active Subscriptions           0.286753                  0.214780
# Number Subscriptions                  0.321008                  0.039029
# Accepts Marketing                     0.085763                 -0.029094
# Total Spent                           0.405957                  0.125389
# Total Orders                          0.516405                  0.123866
# engaged                               0.215912                 -0.239751
#
#                              Has Card Error In Dunning  \
# customer recharge id                          0.017310
# Shopify customer id                           0.017970
# Past Orders Count                            -0.006971
# Has Valid Payment Method                     -0.056022
# Has Card Error In Dunning                     1.000000
# Number Active Subscriptions                   0.017189
# Number Subscriptions                         -0.005936
# Accepts Marketing                            -0.012628
# Total Spent                                  -0.001082
# Total Orders                                  0.003414
# engaged                                      -0.017517
#
#                              Number Active Subscriptions  \
# customer recharge id                            0.164077
# Shopify customer id                             0.156528
# Past Orders Count                               0.286753
# Has Valid Payment Method                        0.214780
# Has Card Error In Dunning                       0.017189
# Number Active Subscriptions                     1.000000
# Number Subscriptions                            0.235621
# Accepts Marketing                               0.060873
# Total Spent                                     0.444811
# Total Orders                                    0.389874
# engaged                                         0.816554
#
#                              Number Subscriptions  Accepts Marketing  \
# customer recharge id                    -0.041853          -0.039983
# Shopify customer id                     -0.045960          -0.047946
# Past Orders Count                        0.321008           0.085763
# Has Valid Payment Method                 0.039029          -0.029094
# Has Card Error In Dunning               -0.005936          -0.012628
# Number Active Subscriptions              0.235621           0.060873
# Number Subscriptions                     1.000000           0.024250
# Accepts Marketing                        0.024250           1.000000
# Total Spent                              0.270582           0.134230
# Total Orders                             0.292131           0.144205
# engaged                                  0.148084           0.071815
#
#                              Total Spent  Total Orders   engaged
# customer recharge id           -0.134057     -0.265358  0.129656
# Shopify customer id            -0.138775     -0.266945  0.122946
# Past Orders Count               0.405957      0.516405  0.215912
# Has Valid Payment Method        0.125389      0.123866 -0.239751
# Has Card Error In Dunning      -0.001082      0.003414 -0.017517
# Number Active Subscriptions     0.444811      0.389874  0.816554
# Number Subscriptions            0.270582      0.292131  0.148084
# Accepts Marketing               0.134230      0.144205  0.071815
# Total Spent                     1.000000      0.797789  0.367092
# Total Orders                    0.797789      1.000000  0.308257
# engaged                         0.367092      0.308257  1.000000

# %%
spearmans = mergedDf.corr(method='spearman')

# %%
spearmans
# Out:
#                              customer recharge id  Shopify customer id  \
# customer recharge id                     1.000000             0.979434
# Shopify customer id                      0.979434             1.000000
# Past Orders Count                       -0.211788            -0.205996
# Has Valid Payment Method                 0.100395             0.100330
# Has Card Error In Dunning                0.021199             0.022008
# Number Active Subscriptions              0.203909             0.194521
# Number Subscriptions                    -0.051744            -0.056778
# Accepts Marketing                       -0.048966            -0.058718
# Total Spent                             -0.198862            -0.204923
# Total Orders                            -0.353295            -0.354867
# engaged                                  0.158784             0.150566
#
#                              Past Orders Count  Has Valid Payment Method  \
# customer recharge id                 -0.211788                  0.100395
# Shopify customer id                  -0.205996                  0.100330
# Past Orders Count                     1.000000                  0.102596
# Has Valid Payment Method              0.102596                  1.000000
# Has Card Error In Dunning            -0.007639                 -0.056022
# Number Active Subscriptions           0.318422                  0.218199
# Number Subscriptions                  0.352277                  0.039374
# Accepts Marketing                     0.093981                 -0.029094
# Total Spent                           0.512063                  0.152862
# Total Orders                          0.598906                  0.142455
# engaged                               0.236601                 -0.239751
#
#                              Has Card Error In Dunning  \
# customer recharge id                          0.021199
# Shopify customer id                           0.022008
# Past Orders Count                            -0.007639
# Has Valid Payment Method                     -0.056022
# Has Card Error In Dunning                     1.000000
# Number Active Subscriptions                   0.017462
# Number Subscriptions                         -0.005989
# Accepts Marketing                            -0.012628
# Total Spent                                  -0.001319
# Total Orders                                  0.003926
# engaged                                      -0.017517
#
#                              Number Active Subscriptions  \
# customer recharge id                            0.203909
# Shopify customer id                             0.194521
# Past Orders Count                               0.318422
# Has Valid Payment Method                        0.218199
# Has Card Error In Dunning                       0.017462
# Number Active Subscriptions                     1.000000
# Number Subscriptions                            0.241034
# Accepts Marketing                               0.061842
# Total Spent                                     0.542540
# Total Orders                                    0.449709
# engaged                                         0.829553
#
#                              Number Subscriptions  Accepts Marketing  \
# customer recharge id                    -0.051744          -0.048966
# Shopify customer id                     -0.056778          -0.058718
# Past Orders Count                        0.352277           0.093981
# Has Valid Payment Method                 0.039374          -0.029094
# Has Card Error In Dunning               -0.005989          -0.012628
# Number Active Subscriptions              0.241034           0.061842
# Number Subscriptions                     1.000000           0.024465
# Accepts Marketing                        0.024465           1.000000
# Total Spent                              0.331226           0.163640
# Total Orders                             0.337514           0.165847
# engaged                                  0.149396           0.071815
#
#                              Total Spent  Total Orders   engaged
# customer recharge id           -0.198862     -0.353295  0.158784
# Shopify customer id            -0.204923     -0.354867  0.150566
# Past Orders Count               0.512063      0.598906  0.236601
# Has Valid Payment Method        0.152862      0.142455 -0.239751
# Has Card Error In Dunning      -0.001319      0.003926 -0.017517
# Number Active Subscriptions     0.542540      0.449709  0.829553
# Number Subscriptions            0.331226      0.337514  0.149396
# Accepts Marketing               0.163640      0.165847  0.071815
# Total Spent                     1.000000      0.907559  0.447525
# Total Orders                    0.907559      1.000000  0.354519
# engaged                         0.447525      0.354519  1.000000

# %%
from scipy.stats import kendalltau, pearsonr, spearmanr

# %%
def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 4)
    return pvalues

# %%
from pandas.plotting import scatter_matrix
attributes = ['Past Orders Count', 'Number Active Subscriptions', 'Number Subscriptions', 'Accepts Marketing', 'Total Spent', 'Total Orders', 'engaged']
scatter_matrix(mergedDf[attributes], figsize=(18, 18))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed47eb8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed47c1a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed4772cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed4724f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed46e0208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed4690470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed46bf6d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed4670908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed4670978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed45d1e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed458f0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed45c4320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed474ee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed46818d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed44d4898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed4509b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed44bcd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed446ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed442e278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed43e14e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed4395748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed43c89b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed437bc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed4331e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed42ef128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed42a3390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed42575f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed4289860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed423dac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed41f0d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed41a3f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed4163240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed41184a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed414b710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed40fe978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed40b4cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed40770f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed402a390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed3fde6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed3f95b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed3fc9c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed3f7cc18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed3f34860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed3ee3be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed3e97f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed3e55320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed3e866a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed3e38a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0ed3de9da0>]],
#       dtype=object)

# %% [markdown]
# ## Regression Analysis

# %%
import statsmodels.api as sm 
import pandas.util.testing as tm
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
mergedDf.describe()
# Out:
#        customer recharge id  Shopify customer id  Past Orders Count  \
# count          6.967000e+03         6.967000e+03        6967.000000
# mean           3.915781e+07         2.877119e+12           2.290656
# std            7.103050e+06         4.796985e+11           1.630196
# min            3.141258e+07         2.146196e+12           0.000000
# 25%            3.310591e+07         2.441368e+12           1.000000
# 50%            3.624204e+07         2.855492e+12           2.000000
# 75%            4.367831e+07         3.239227e+12           3.000000
# max            5.686593e+07         3.810865e+12          16.000000
#
#        Number Active Subscriptions  Number Subscriptions  Accepts Marketing  \
# count                  6967.000000           6967.000000        6967.000000
# mean                      0.485001              1.139515           0.798766
# std                       0.580596              0.450920           0.400952
# min                       0.000000              1.000000           0.000000
# 25%                       0.000000              1.000000           1.000000
# 50%                       0.000000              1.000000           1.000000
# 75%                       1.000000              1.000000           1.000000
# max                       4.000000             10.000000           1.000000
#
#        Total Spent  Total Orders      engaged
# count  6967.000000   6967.000000  6967.000000
# mean    234.535226      4.030429     0.516578
# std     255.341019      3.676433     0.499761
# min       0.000000      0.000000     0.000000
# 25%      89.980000      2.000000     0.000000
# 50%     169.960000      3.000000     1.000000
# 75%     299.940000      5.000000     1.000000
# max    3928.350000     48.000000     1.000000

# %%
active = mergedDf[mergedDf['engaged']==1]
inactive = mergedDf[mergedDf['engaged']==0]

# active.drop(['customer recharge id', 'Shopify customer id'], axis=1)
del active['customer recharge id']
del active['Shopify customer id']

del inactive['Shopify customer id']
del inactive['customer recharge id']

# %%
active.describe()
# Out:
#        Past Orders Count  Number Active Subscriptions  Number Subscriptions  \
# count        3599.000000                  3599.000000           3599.000000
# mean            2.685468                     0.925257              1.202001
# std             1.869859                     0.488015              0.535599
# min             0.000000                     0.000000              1.000000
# 25%             1.000000                     1.000000              1.000000
# 50%             2.000000                     1.000000              1.000000
# 75%             3.000000                     1.000000              1.000000
# max            16.000000                     4.000000              7.000000
#
#        Accepts Marketing  Total Spent  Total Orders  engaged
# count        3599.000000  3599.000000   3599.000000   3599.0
# mean            0.826619   320.380767      5.174771      1.0
# std             0.378629   310.193026      4.374018      0.0
# min             0.000000     0.000000      0.000000      1.0
# 25%             1.000000   138.140000      2.000000      1.0
# 50%             1.000000   245.950000      4.000000      1.0
# 75%             1.000000   385.640000      6.000000      1.0
# max             1.000000  3928.350000     48.000000      1.0

# %%
inactive.describe()
# Out:
#        Past Orders Count  Number Active Subscriptions  Number Subscriptions  \
# count        3368.000000                  3368.000000           3368.000000
# mean            1.868765                     0.014549              1.072743
# std             1.190497                     0.119755              0.324789
# min             0.000000                     0.000000              1.000000
# 25%             1.000000                     0.000000              1.000000
# 50%             2.000000                     0.000000              1.000000
# 75%             2.000000                     0.000000              1.000000
# max            15.000000                     1.000000             10.000000
#
#        Accepts Marketing  Total Spent  Total Orders  engaged
# count        3368.000000  3368.000000   3368.000000   3368.0
# mean            0.769002   142.801823      2.807601      0.0
# std             0.421533   125.597475      2.150233      0.0
# min             0.000000     0.000000      0.000000      0.0
# 25%             1.000000    54.990000      1.000000      0.0
# 50%             1.000000   102.930000      2.000000      0.0
# 75%             1.000000   182.280000      4.000000      0.0
# max             1.000000  1983.690000     34.000000      0.0

# %%
mergedDf.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['customer recharge id', 'customer first name', 'customer last name',
#        'Email', 'created at', 'status', 'shipping address 1',
#        'shipping address 2', 'shipping city', 'shipping postal code',
#        'shipping province', 'shipping country', 'shipping_phone', 'portal_url',
#        'billing address 1', 'billing address 2', 'billing city',
#        'billing postal code', 'billing province', 'billing country',
#        'Shopify customer id', 'Past Orders Count', 'Has Valid Payment Method',
#        'Reason Payment Method Not Valid', 'Has Card Error In Dunning',
#        'Number Active Subscriptions', 'Number Subscriptions',
#        'First Charge Processed At', 'First Name', 'Last Name', 'Company',
#        'Address1', 'Address2', 'City', 'Province', 'Province Code', 'Country',
#        'Country Code', 'Zip', 'Phone', 'Accepts Marketing', 'Total Spent',
#        'Total Orders', 'Tags', 'Note', 'Tax Exempt', 'engaged'],
#       dtype='object')>

# %%
mergedDf.dtypes
# Out:
# customer recharge id                 int64
# customer first name                 object
# customer last name                  object
# Email                               object
# created at                          object
# status                              object
# shipping address 1                  object
# shipping address 2                  object
# shipping city                       object
# shipping postal code                object
# shipping province                   object
# shipping country                    object
# shipping_phone                      object
# portal_url                          object
# billing address 1                   object
# billing address 2                   object
# billing city                        object
# billing postal code                 object
# billing province                    object
# billing country                     object
# Shopify customer id                  int64
# Past Orders Count                    int64
# Has Valid Payment Method              bool
# Reason Payment Method Not Valid     object
# Has Card Error In Dunning             bool
# Number Active Subscriptions          int64
# Number Subscriptions                 int64
# First Charge Processed At           object
# First Name                          object
# Last Name                           object
# Company                             object
# Address1                            object
# Address2                            object
# City                                object
# Province                            object
# Province Code                       object
# Country                             object
# Country Code                        object
# Zip                                 object
# Phone                               object
# Accepts Marketing                    int64
# Total Spent                        float64
# Total Orders                         int64
# Tags                                object
# Note                                object
# Tax Exempt                          object
# engaged                              int64
# dtype: object

# %%
continuous_vars = [
                   'Past Orders Count',
                   'Number Active Subscription',
                   'Number Subscriptions',
                   'Total Spent',
                   'Total Orders'
]

# %%
logit = sm.Logit(
    mergedDf['engaged'],
    mergedDf[['Past Orders Count', 
              'Number Active Subscriptions', 
              'Number Subscriptions', 
              'Total Spent', 
              'Total Orders']]
)

# %%
logit_fit = logit.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.270812
#          Iterations 8

# %%
logit_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                engaged   No. Observations:                 6967
# Model:                          Logit   Df Residuals:                     6962
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 13 Jan 2021   Pseudo R-squ.:                  0.6090
# Time:                        01:51:40   Log-Likelihood:                -1886.7
# converged:                       True   LL-Null:                       -4825.3
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Past Orders Count              -0.1303      0.042     -3.101      0.002      -0.213      -0.048
# Number Active Subscriptions     6.1187      0.174     35.264      0.000       5.779       6.459
# Number Subscriptions           -1.3584      0.080    -16.905      0.000      -1.516      -1.201
# Total Spent                     0.0037      0.001      5.565      0.000       0.002       0.005
# Total Orders                   -0.1974      0.044     -4.450      0.000      -0.284      -0.110
# ===============================================================================================
# """

# %% [markdown]
# ## Decision Trees
